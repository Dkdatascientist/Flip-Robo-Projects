# %% [markdown]
# # Web Scraping for Ratting Project Part - 2

# %%
#importing the required library
from selenium import webdriver
from bs4 import BeautifulSoup
import pandas as pd

# %%
HREF = pd.read_csv('HREF2.csv') #importing the saved URL(Tabel 2)

# %%
hreff = [] #creating list from the data frame.
for i in HREF['URL']:
    hreff.append(i)

# %%
def get_review(): #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome() #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff: #--->> Second DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5): #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings2.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#       Rattings                                             Review
# 0            5  These are the best budget headphones.I have ne...
# 1            4  Good product, nice build quality, the only thi...
# 2            5  It was awesome headset. It gave me a amazing g...
# 3            4  This is a decent gaming headset at a good pric...
# 4            5  Using for almost 3 months nice performanceFor ...
# ...        ...                                                ...
# 11742        1  I Placed my  mobile at the  stand and they’re ...
# 11743        1  Light is not working after 2 weeks, saler is n...
# 11744        5  It is a very good light. Upto my expectations....
# 11745        1  The neck has a ball n it keeps falling with th...
# 11746        5  Easy to assemble, good brightness good return ...
#
# [11747 rows x 2 columns]

# %%
HREF = pd.read_csv('HREF3.csv') #importing the saved URL(Tabel 3)

# %%
hreff = [] #creating list from the data frame.
for i in HREF['URL']:
    hreff.append(i)

# %%
def get_review(): #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome() #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff: #--->> third DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5): #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings3.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#      Rattings                                             Review
# 0           3  Go for Fujifilm X-T30 at a lowest price, you'l...
# 1           1  It does not fit the screen for D7200, waste of...
# 2           2  It was not of proper size. I had to cut it in ...
# 3           1  Poor not currect size ...its bigger than the s...
# 4           1                           Over sized not for D7200
# ...       ...                                                ...
# 7896        5                                      Great product
# 7897        1                     Very bad product..never buy it
# 7898        4  smart product in field of education, but pictu...
# 7899        5  Good product and very useful for book scanning...
# 7900        1  Didnt had the updated software  and very less ...
#
# [7901 rows x 2 columns]

# %%
HREF = pd.read_csv('HREF5.csv') #importing the saved URL(Tabel 5)
hreff = [] #creating list from the data frame.
for i in HREF['URL']:
    hreff.append(i)

def get_review(): #the function that scraps the URL of all the reviews and rattings
    
    driver = webdriver.Chrome() #Calling the Web Driver
    driver.maximize_window()
    rattings = []
    review = []

    for i in hreff: #--->> Fifth DataFrame
        driver.get(i) #Opening with the URL template
        
        try: #scraping the URL of the full review pages
            link = driver.find_element_by_xpath("//a[@data-hook='see-all-reviews-link-foot']")
            link = link.get_attribute("href")
            link= link.split('ref=cm')[0]
        except:
            pass     
        
        for i in range(1,5):  #Scraping Reviews and Rattings
            l1= f'ref=cm_cr_getr_d_paging_btm_next_{i}?ie=UTF8&reviewerType=all_reviews&pageNumber={i}'
            l = link+ l1 
            
            
            driver.get(l)
            
            soup = BeautifulSoup(driver.page_source, 'html.parser')
            results = soup.find_all('div',{'class' : 'a-section celwidget'})
        
            for item in results:
                    try:
                        rev = item.find('span', {'data-hook': "review-body"})
                        atag = item.find(['a'], class_ = "a-link-normal")
                        if rev.span.text.replace('\n','').strip() and atag['title'][0]:
                            review.append(rev.span.text.replace('\n','').strip())
                            rattings.append(atag['title'][0])
                        else:
                            break
                    except:
                        break
       
    driver.close()
    
    rat = pd.DataFrame({'Rattings':rattings, "Review": review})
    
    #saving the dataframe in csv
    rat.to_csv("Rattings5.csv",index=False) #Creating CSV
    
    return rat

# %%
Rat = get_review()
Rat
# Out:
#       Rattings                                             Review
# 0            3  Recieved the product early than expected.produ...
# 1            4  Good. But product looks different from picture...
# 2            4  Its good, simply to cover and protect your des...
# 3            3  got a while colored cheaper quality cover ... ...
# 4            1                                      Cheap quality
# ...        ...                                                ...
# 10196        1  I've been using this router for many years. Ti...
# 10197        1  GUYS PLEASE PLEASE AVOID THIS ROUTER AT ALL CO...
# 10198        5  As others have already said in their reviews, ...
# 10199        1  20th Jan 2021 ::  I purchased this router on t...
# 10200        1  It was a mistake buying this router. Points to...
#
# [10201 rows x 2 columns]

# %% [markdown]
# Importing all the data and concatenating into a single CSV file

# %%
rattings1, rattings2, rattings3, rattings4, rattings5 = pd.read_csv('Rattings1.csv'), pd.read_csv('Rattings2.csv'), pd.read_csv('Rattings3.csv'), pd.read_csv('Rattings4.csv'),pd.read_csv('Rattings5.csv')

# %%
frames = [rattings1, rattings2, rattings3, rattings4, rattings5]
Rattings = pd.concat(frames)

# %%
Rattings #we have collected 50593 records of data
# Out:
#        Rattings                                             Review
# 0             4  Received this yesterday (04/03/2021). Prompt d...
# 1             1  Different charger was sent in the box by Amazo...
# 2             5  Amazing laptop.. I ordered this laptop on its ...
# 3             4  As soon as I found 11gen Gen i5 at ~62K I got ...
# 4             5  I bought this a few days ago, and I am glad I ...
# ...         ...                                                ...
# 10196         1  I've been using this router for many years. Ti...
# 10197         1  GUYS PLEASE PLEASE AVOID THIS ROUTER AT ALL CO...
# 10198         5  As others have already said in their reviews, ...
# 10199         1  20th Jan 2021 ::  I purchased this router on t...
# 10200         1  It was a mistake buying this router. Points to...
#
# [50593 rows x 2 columns]

# %%
Rattings.to_csv("Rattings.csv",index=False)# saving Data frame as CSV
